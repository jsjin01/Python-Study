# %%
#자료형
#1. 숫자형, 문자열, 불 - 자료에 대한 타입
#2. 변수, 리스트, 튜플, 딕셔너리, 집합 - 어떤 값을 담는 자료구조

1.1 숫자형
int(정수형) (1, 2, 3)
float(실수형) (1.24, -34.56)
컴퓨터식 지수 표현 방식(4.24e10, 4.24e-10)

자료가 무슨 형인지 궁금할 때 예시
a=1

print(type(a))

숫자형 연산
덧셈 +
뺄셈 -
곱셈 *
나눗셈 /
몫 //
나머지 %
제곱 **

1.2 문자열 자료형
string
큰 따옴표, 작은 따옴표로 문자열 자료형을 만들 수 있음
 예시  = 'Python's favorite food is pearl'
    ㄴ 'Python'만 문자열 자료형으로 인식하고 뒷 문장을 인식하지 못함
    그래서 "" 큰 따옴표를 쓰는 것이 좋음
    \'를 쓰면 문자열 따옴표를 쓴다는 의미를 나타냄
    \n을 사용하면 문장을 띄울 수 있음
    \t 문자열에서 탭 간격을 줄 때사용
    \\ 문자 \를 표현할 때 사용

인덱싱(indexing) - 특정 위치 접근
    a = "life is short"
         0123456789 자리순서
         역순이면 trohs가 -1 -2 -3 -4 -5 자리임     

    print(a[0])는 "ㅣ"
    print(a[2])는 "f"
    print(a[-1])는 "t"
    print(a[-2])는 "r"
    print(a[0:5])는 "Life i"

슬라이싱(slicing) - 특정 범위 추출출
    a[이상:미만:간격이 들어가는 자리]
    print(a[:8])는 "life is s"
    print(a[::2])는 "iei sot"

문자열 포매팅
"I eat %d apples." % 3
='I eat 3 apples'
number = 10
day = three
"I ate %d apples. so I was sick for %s days." % (number, day)
='I ate 10 apples. so I was sick for three days.'

문자열 포맷 코드
# %s 문자열(String)
# %c 문자 1개(Character)
# %d 정수(Integer)
# %f 부동 소수(Floating-point)
# %o 8진수(8진수)
# %x 16진수(16진수)
%% Literal %(문자 '%' 자체)

format 함수
a= "aaassd {} adsdsds".format("안녕")
print(a)
결과값 aaassd 안녕 adsdsds

a= "aaassd {age} adsdsds {name}".format(name="안녕", age=3)
결과값 aaassd 3 adsdsds 안녕

name = "int"
a = f"나의 이름은 {name}입니다"
print(a)
결과값 나의 이름은 int 입니다

정렬과 공백
"%10s" % "hi"
'         hi'
"%-10sjane." % 'hi"
'hi      jane.'

소수점 표현
"%0.4f" % 3.42134234
'3.4213'
"%10.4f" % 3.42134234
'    3.4213'

문자열 개수 세기
a = "hobby"
a.count('b')
2 - b의 개수가 2개여서 2임

위치 알려주기1(find)
a= "python is best choice"
a.find('b')
10
a.find('k')
-1  - 찾을 수 없어서 결과값이 -1이 나옴

위치 알려주기2(index)
문자열 삽입(join)
소문자를 대문자로 바꾸기(upper)
대문자를 소문자로 바꾸기(lower)
공백 없애기(strip)
문자열 바꾸기(replace)
문자열 나누기(split)

리스트 자료형형
