# %% [markdown]
# 자료형
# 값의 타입.
# 숫자, 문자열, 불, 변수, 리스트, 튜플, 딕셔너리, 집합 등
#
# 숫자형 - 정수 실수 (지수 8진수 16진수 등)
#
# 곱하기 *
# 제곱 **
# 나누기 /
# 몫 //
# 나머지 %
#
#
# 문자형 만드는 방법
# 1. 큰 따옴표 " "
# 2. 작은 따옴표 ' '
# 3. 큰 따옴표 3개 """ """
# 4. 작은 따옴표 3개 ''' '''
# +문장 안에 따옴표 포함시키기:'~  \' ~ '
# ++이스케이프 문자 \n( 줄바꿈)
# +++여러 문장을 사용할 경우 따옴표 3개가 유용
#
# 글자에 곱하기 가능. 곱한 만큼 출력
#
# 문장에 인덱싱 적용.
# a = "life"
# print(a[0])
# 결과 l 출력
# 슬라이싱 a[이상:미만:간격]
# 간격에는 -1등 음수값 가능. 그 경우 역으로 읽음
#
# %c %s %d %f 문자1개개 문자열 정수 실수
# a = "abc{age} abc {name}".format(name="김" age=20)
# 변수에 맞게 적용
#
# 문자열 개수 세기 count
# 문자열 위치 찾기 find
# 없으면 -1 반환
# 문자열 삽입 죠인 join
# a = ","
# a.join('abcd')
# abcd를 쪼개고 사이에 ,를 삽입.
# -> a,b,c,d
#
# 소문자를 대문자로 -> a.upper()
# 대문자를 소문자로 -> a.lower()
#
# 양쪽 공백 지우기 strip
#
# 기준으로 리스트 만들기
# split
# a = "a:b:c:d"
# print(a.split(":"))#()내용을 통해 구분
# 결과
# ['a', 'b', 'c', 'd']
#
# 리스트 안에 리스트 작성 가능
# 리스트끼리 +로 합칠 수 있음.
# 곱하기 가능.
#
# del 요소 삭제
# append 맨 뒤에 요소 추가
# sort 정렬
# reverse 뒤집기
# index 위치 찾기
# insert 원하는 위치에 요소 삽입
# remove 앞에서부터 일치하는 값 하나 제거.
# pop 리스트 마지막 요소 꺼내기
# count 요소 개수 세기
# extend 맨 뒤에 리스트 추가
#
# 리스트를 쓰는 이유: 변수들을 한 번에 관리하기 위해 사용함
#
# 튜플
# a = (1,2,3)
# 리스트는 append 등으로 요소 추가 가능.
# 튜플은 고정되어 변경 불가능. (길이와 값이 고정)
#
# 딕셔너리
# 키로 설정한 단어를 검색색해서 값을 확인하는 것.
# API에 자주 활용
# 이름:값의 패턴으로 활용.
# 연관 배열 또는 해시라고 불림
# 값은 중복되더라도 키는 중복되면 안된다.
#
# 집합
# 중복된 요소를 가질 수 없다.
# 순서가 없다.
#
# 정의:
# s1 = set([1,2,3])
# s1 = {1,2,3}
# 리스트의 중복을 없애는 경우에도 사용 가능
# 문자열도 집합으로 할 경우 순서 없이 글자로 쪼개진다.
#
# 불(참 거짓)
#
# True False
#
# 자료형의 참 거짓.
# 자료형의 값이 존재하면 참, 없으면 거짓.
# 숫자형 1은 참, 0은 거짓.
# None은 거짓.

# %%
#변수
a = 1

print(type(a))

b = 4.2e10
print(b)
print(type(b))

#format
a = "abc{age} abc {name}".format(name="김", age=20)
print(a)

#문자열 개수 세기
a = "hobby"

print(a.count('b'))   #b가 들어가는 횟수
print(a.find('b'))    #b의 인덱스 번호호

#문자열 삽입
a = ","
print(a.join('abcd'))

#소문자를 대문자로 바꾸기
a = "hi"
print(a.upper())

#튜플
t1 = (1,2,'a','b')
#t1[0] = 2 불가능. 인덱싱, 슬라이싱은 가능.
#a = a*3의 경우 a*3으로 새롭게 정의하는 것. 수정이 아님

#딕셔너리
dic = {'name':'ERIC','age':15}
print(dic)

a = {1:'a'}
print(a)

a['name'] = "익명"
print(a)

del a[1] #삭제 시 키를 통해해 삭제
print(a)

print(a.keys()) #키만 출력. 
print(a.values()) #값만 출력
print(a.items()) #키, 값 쌍으로 출력
for v in a.keys():
    print("키:",v)
for k, v in dic.items():
    print(k,v)

#a.clear() # 모두 지우기
#a[4]의 경우 해당하는 키가 없으면 오류가 발생하지만 a.get(4)의 경우 None이 출력된다.
#a.get(4,'없음')으로 없는 경우 리턴할 값을 지정할 수 있다.
#print(4 in a)를 통해 키가 딕셔너리 안에 있는지 불리언 값으로 확인 가능

#리스트
l1 = [1,2,2,3,3]
newList = list(set(l1)) #리스트의 중복을 제거한 후 다시 리스트로 만듦듦
print(newList)

#교집합 &
s1 = set([1,2,3,4,5,6])
s2 = set([4,5,6,7,8,9])
print(s1 & s2) #print(s1.intersection(s2))로도 사용 가능

#합집합
print(s1 | s2) # == s1.union(s2)

#차집합
print(s1 - s2) # == s1.difference(s2)

#값 추가 add, update
s1.add(7) #한 개 추가가
print(s1)
s1.update([7,8,9]) # 여러개 추가

#특정 값 제거
s1.remove(7)
print(s1)

#불
a = "가"
if a:
    print(a)

b = [1,2,3,4]
while b:
    b.pop()
    print(b)
